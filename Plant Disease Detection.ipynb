# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.image as img
import cv2
import dask
from PIL import Image
import matplotlib.pyplot as plt
image=cv2.imread("/home/rahul/Projects/Agriculture/Data Science/Data/dataset/train/Apple___Apple_scab/08c42d78-aa7b-4106-b0c1-b260f898dcba___FREC_Scab 3151.JPG")
image_to_array=Image.fromarray(image,"RGB")  
size_image=image_to_array.resize((200,200))
plt.imshow(size_image)

# %%
import glob
np.array(glob.glob("/home/rahul/Projects/Agriculture/Data Science/Data/dataset/train/*/*.JPG")).shape
# Out:
# (42244,)

# %%
data1=[]
labels1=[]
# %time
for i in range(250):
    image=cv2.imread(np.array(glob.glob("/home/rahul/Projects/Agriculture/Data Science/Data/dataset/train/Tomato*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("/home/rahul/Projects/Agriculture/Data Science/Data/dataset/train/Tomato*/*.JPG"))[i])
# Out:
# CPU times: user 10 µs, sys: 2 µs, total: 12 µs
# Wall time: 23.6 µs

# %%
np.array(data1).shape
# Out:
# (250, 200, 200, 3)

# %%
X_train=np.array(data1)

# %%
import re
Labels=[]
for i in range(14401):
    Labels.append(re.split(r'/',labels1[i])[5])
Labels=np.array(Labels).reshape(-1,1)

# %%
from sklearn.preprocessing import OrdinalEncoder 
encoder=OrdinalEncoder()
y_train=encoder.fit_transform(Labels)

# %%
encoder.categories_

# %%
import tensorflow as tf
import tensorflow.keras as keras
from keras.utils import to_categorical
no_classes=10
ytr=to_categorical(y_train,no_classes)
# Out:
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rahul/miniconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-53918708a6f4> in <module>
#       1 import tensorflow as tf
#       2 import tensorflow.keras as keras
# ----> 3 from keras.utils import to_categorical
#       4 no_classes=10
#       5 ytr=to_categorical(y_train,no_classes)
#
# ModuleNotFoundError: No module named 'keras'

# %%
from keras.models import Sequential
from keras.layers import  Dense, Dropout, Flatten, Conv2D, MaxPooling2D
model=Sequential()
model.add(Conv2D(filters=16,kernel_size=3,padding="same",activation="relu",input_shape=(200,200,3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32,kernel_size=3,padding="same",activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64,kernel_size=3,padding="same",activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64,kernel_size=3,padding="same",activation="relu"))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(500,activation="relu"))
model.add(Dense(10,activation="softmax"))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4587f5fc9759> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import  Dense, Dropout, Flatten, Conv2D, MaxPooling2D
#       3 model=Sequential()
#       4 model.add(Conv2D(filters=16,kernel_size=3,padding="same",activation="relu",input_shape=(200,200,3)))
#       5 model.add(MaxPooling2D(pool_size=2))
#
# ModuleNotFoundError: No module named 'keras'

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=500
epochs=40
predict=model.fit(X_train,ytr,batch_size=batch_size,epochs=epochs)

# %%
for i in range(2537):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Apple*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Apple*/*.JPG"))[i])

# %%
for i in range(1202):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Blue*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Blue*/*.JPG"))[i])

# %%
for i in range(1526):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Cherry*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Cherry*/*.JPG"))[i])

# %%
for i in range(2021):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Corn*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Corn*/*.JPG"))[i])

# %%
for i in range(3251):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Grape*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Grape*/*.JPG"))[i])

# %%
for i in range(4406):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Orange*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Orange*/*.JPG"))[i])

# %%
for i in range(2126):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Peach*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Peach*/*.JPG"))[i])

# %%
for i in range(1979):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Pepper*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Pepper*/*.JPG"))[i])

# %%
for i in range(1722):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Potato*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Potato*/*.JPG"))[i])

# %%
for i in range(297):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Raspberry*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Raspberry*/*.JPG"))[i])

# %%
for i in range(4072):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Soybean*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Soybean*/*.JPG"))[i])

# %%
for i in range(1452):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Squash*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Squash*/*.JPG"))[i])

# %%
for i in range(1252):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Strawberry*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Strawberry*/*.JPG"))[i])

# %%
for i in range(14401):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Tomato*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data1.append(np.array(size_image))
    labels1.append(np.array(glob.glob("../input/dataset/dataset/train/Tomato*/*.JPG"))[i])

# %%
data1=[]
labels1=[]
# %time

# %%
np.array(glob.glob("../input/dataset/dataset/train/Blue*/*.JPG")).shape

# %%
# %time
for i in range(1202):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Blue*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data.append(np.array(size_image))
    labels.append(np.array(glob.glob("../input/dataset/dataset/train/Blue*/*.JPG"))[i])

# %%
np.array(glob.glob("../input/dataset/dataset/train/Cherry*/*.JPG")).shape

# %%
# %time
for i in range(1526):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/Cherry*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data.append(np.array(size_image))
    labels.append(np.array(glob.glob("../input/dataset/dataset/train/Cherry*/*.JPG"))[i])

# %%
np.array(glob.glob("../input/dataset/dataset/train/Corn*/*.JPG")).shape

# %%
data=[]
labels=[]
# %time
for i in range(2021):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/Corn/*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data.append(np.array(size_image))
    labels.append(np.array(glob.glob("../input/dataset/dataset/Corn/*/*.JPG"))[i])

# %%
data=[]
labels=[]
# %time
for i in range(42244):
    image=cv2.imread(np.array(glob.glob("../input/dataset/dataset/train/*/*.JPG"))[i])
    image_to_array=Image.fromarray(image,"RGB")
    size_image=image_to_array.resize((200,200))
    data.append(np.array(size_image))
    labels.append(np.array(glob.glob("../input/dataset/dataset/train/*/*.JPG"))[i])

# %%
X_train=np.array(data)
X_train.shape
Labels1=np.array(labels)
Labels1.shape

# %%
Labels=[]
for i in range(42244):
    Labels.append(re.split(r'/',Labels1[i])[5])
Labels=np.array(Labels).reshape(-1,1)

# %%
from sklearn.preprocessing import OrdinalEncoder 
encoder=OrdinalEncoder()
y_train=encoder.fit_transform(Labels)

# %%
Labels.shape

# %%
import requests
data=requests.get('kaggle datasets download -d saroz014/plant-disease')
